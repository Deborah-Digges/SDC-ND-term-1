# %% [markdown]
# Deep Learning
# =============
#
# Assignment 2
# ------------
#
# Previously in `1_notmnist.ipynb`, we created a pickle with formatted datasets for training, development and testing on the [notMNIST dataset](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html).
#
# The goal of this assignment is to progressively train deeper and more accurate models using TensorFlow.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %% [markdown]
# First reload the data we generated in `1_notmnist.ipynb`.

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a shape that's more adapted to the models we're going to train:
# - data as a flat matrix,
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
hidden_layer_size = 1024

def reformat(dataset, labels):
  dataset = dataset.reshape((-1, image_size * image_size)).astype(np.float32)
  # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 784) (200000, 10)
# Validation set (10000, 784) (10000, 10)
# Test set (10000, 784) (10000, 10)

# %% [markdown]
# We're first going to train a multinomial logistic regression using simple gradient descent.
#
# TensorFlow works like this:
# * First you describe the computation that you want to see performed: what the inputs, the variables, and the operations look like. These get created as nodes over a computation graph. This description is all contained within the block below:
#
#       with graph.as_default():
#           ...
#
# * Then you can run the operations on this graph as many times as you want by calling `session.run()`, providing it outputs to fetch from the graph that get returned. This runtime operation is all contained in the block below:
#
#       with tf.Session(graph=graph) as session:
#           ...
#
# Let's load all the data into TensorFlow and build the computation graph corresponding to our training:

# %%
# With gradient descent training, even this much data is prohibitive.
# Subset the training data for faster turnaround.
train_subset = 10000

graph = tf.Graph()
with graph.as_default():

  # Input data.
  # Load the training, validation and test data into constants that are
  # attached to the graph.
  tf_train_dataset = tf.constant(train_dataset[:train_subset, :])
  tf_train_labels = tf.constant(train_labels[:train_subset])
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  # These are the parameters that we are going to be training. The weight
  # matrix will be initialized using random values following a (truncated)
  # normal distribution. The biases get initialized to zero.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, hidden_layer_size]))
  biases1 = tf.Variable(tf.zeros([hidden_layer_size]))
  weights2 = tf.Variable(
    tf.truncated_normal([hidden_layer_size, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  # We multiply the inputs with the weight matrix, and add biases. We compute
  # the softmax and cross-entropy (it's one operation in TensorFlow, because
  # it's very common, and it can be optimized). We take the average of this
  # cross-entropy across all training examples: that's our loss.
  logits1 = tf.matmul(tf_train_dataset, weights1) + biases1 
  hidden_layer_output = tf.nn.relu(logits1)
  a2 = tf.matmul(hidden_layer_output, weights2)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(a2, tf_train_labels))
  
  # Optimizer.
  # We are going to find the minimum of this loss using gradient descent.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  # These are not part of training, but merely here so that we can report
  # accuracy figures as we train.
  train_prediction = tf.nn.softmax(a2)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1), weights2))
  test_prediction = tf.nn.softmax(
    tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1), weights2))
  init = tf.initialize_all_variables()

# %% [markdown]
# Let's run this computation and iterate:

# %%
num_steps = 801

def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])


with tf.Session(graph=graph) as session:
  # This is a one-time operation which ensures the parameters get initialized as
  # we described in the graph: random weights for the matrix, zeros for the
  # biases. 
  session.run(init)
  print('Initialized')
  for step in range(num_steps):
    # Run the computations. We tell .run() that we want to run the optimizer,
    # and get the loss value and the training predictions returned as numpy
    # arrays.
    _, l, predictions = session.run([optimizer, loss, train_prediction])
    if (step % 100 == 0):
      print('Loss at step %d: %f' % (step, l))
      print('Training accuracy: %.1f%%' % accuracy(
        predictions, train_labels[:train_subset, :]))
      # Calling .eval() on valid_prediction is basically like calling run(), but
      # just to get that one numpy array. Note that it recomputes all its graph
      # dependencies.
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Loss at step 0: 366.783112
# Training accuracy: 4.2%
# Validation accuracy: 39.6%
# Loss at step 100: 3.833670
# Training accuracy: 92.2%
# Validation accuracy: 78.7%
# Loss at step 200: 0.158922
# Training accuracy: 99.5%
# Validation accuracy: 79.5%
# Loss at step 300: 0.065299
# Training accuracy: 99.8%
# Validation accuracy: 79.5%
# Loss at step 400: 0.057493
# Training accuracy: 99.8%
# Validation accuracy: 79.4%
# Loss at step 500: 0.075780
# Training accuracy: 99.8%
# Validation accuracy: 79.6%
# Loss at step 600: 0.087898
# Training accuracy: 99.7%
# Validation accuracy: 79.7%
# Loss at step 700: 0.207670
# Training accuracy: 99.7%
# Validation accuracy: 80.0%
# Loss at step 800: 0.020789
# Training accuracy: 99.9%
# Validation accuracy: 79.5%
# Test accuracy: 87.3%

# %% [markdown]
# Let's now switch to stochastic gradient descent training instead, which is much faster.
#
# The graph will be similar, except that instead of holding all the training data into a constant node, we create a `Placeholder` node which will be fed actual data at every call of `session.run()`.

# %%
batch_size = 128

graph = tf.Graph()
with graph.as_default():

  # Input data. For the training data, we use a placeholder that will be fed
  # at run time with a training minibatch.
  tf_train_dataset = tf.placeholder(tf.float32,
                                    shape=(batch_size, image_size * image_size))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  # These are the parameters that we are going to be training. The weight
  # matrix will be initialized using random values following a (truncated)
  # normal distribution. The biases get initialized to zero.
  weights1 = tf.Variable(
    tf.truncated_normal([image_size * image_size, hidden_layer_size]))
  biases1 = tf.Variable(tf.zeros([hidden_layer_size]))
  weights2 = tf.Variable(
    tf.truncated_normal([hidden_layer_size, num_labels]))
  biases2 = tf.Variable(tf.zeros([num_labels]))
  
  # Training computation.
  # We multiply the inputs with the weight matrix, and add biases. We compute
  # the softmax and cross-entropy (it's one operation in TensorFlow, because
  # it's very common, and it can be optimized). We take the average of this
  # cross-entropy across all training examples: that's our loss.
  logits1 = tf.matmul(tf_train_dataset, weights1) + biases1 
  hidden_layer_output = tf.nn.relu(logits1)
  a2 = tf.matmul(hidden_layer_output, weights2)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(a2, tf_train_labels))
  
  # Optimizer.
  # We are going to find the minimum of this loss using gradient descent.
  optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  # These are not part of training, but merely here so that we can report
  # accuracy figures as we train.
  train_prediction = tf.nn.softmax(a2)
  valid_prediction = tf.nn.softmax(
    tf.matmul(tf.nn.relu(tf.matmul(tf_valid_dataset, weights1) + biases1), weights2))
  test_prediction = tf.nn.softmax(
    tf.matmul(tf.nn.relu(tf.matmul(tf_test_dataset, weights1) + biases1), weights2))
  init = tf.initialize_all_variables()

# %% [markdown]
# Let's run it:

# %%
num_steps = 3001

with tf.Session(graph=graph) as session:
  print("Initialized")
  session.run(init)
  for step in range(num_steps):
    # Pick an offset within the training data, which has been randomized.
    # Note: we could use better randomization across epochs.
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    # Generate a minibatch.
    batch_data = train_dataset[offset:(offset + batch_size), :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    # Prepare a dictionary telling the session where to feed the minibatch.
    # The key of the dictionary is the placeholder node of the graph to be fed,
    # and the value is the numpy array to feed to it.
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 1 == 0):
      print("Minibatch loss at step %d: %f" % (step, l))
      print("Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels))
      print("Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels))
  print("Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 359.201172
# Minibatch accuracy: 7.8%
# Validation accuracy: 32.1%
# Minibatch loss at step 1: 1221.627686
# Minibatch accuracy: 29.7%
# Validation accuracy: 24.2%
# Minibatch loss at step 2: 2075.334961
# Minibatch accuracy: 27.3%
# Validation accuracy: 37.5%
# Minibatch loss at step 3: 1223.377808
# Minibatch accuracy: 25.0%
# Validation accuracy: 43.3%
# Minibatch loss at step 4: 439.642700
# Minibatch accuracy: 39.1%
# Validation accuracy: 44.5%
# Minibatch loss at step 5: 680.631592
# Minibatch accuracy: 43.8%
# Validation accuracy: 56.5%
# Minibatch loss at step 6: 340.206238
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.3%
# Minibatch loss at step 7: 168.978455
# Minibatch accuracy: 68.0%
# Validation accuracy: 73.1%
# Minibatch loss at step 8: 148.424011
# Minibatch accuracy: 73.4%
# Validation accuracy: 73.5%
# Minibatch loss at step 9: 81.572693
# Minibatch accuracy: 78.1%
# Validation accuracy: 73.0%
# Minibatch loss at step 10: 172.035797
# Minibatch accuracy: 78.1%
# Validation accuracy: 71.9%
# Minibatch loss at step 11: 83.268616
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.5%
# Minibatch loss at step 12: 45.910980
# Minibatch accuracy: 78.1%
# Validation accuracy: 76
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.7%
# Minibatch loss at step 2882: 6.516383
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 2883: 7.910815
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.2%
# Minibatch loss at step 2884: 4.278649
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.8%
# Minibatch loss at step 2885: 2.190351
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 2886: 7.596075
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.0%
# Minibatch loss at step 2887: 2.208848
# Minibatch accuracy: 88.3%
# Validation accuracy: 81.8%
# Minibatch loss at step 2888: 2.645309
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.2%
# Minibatch loss at step 2889: 4.520001
# Minibatch accuracy: 82.8%
# Validation accuracy: 78.6%
# Minibatch loss at step 2890: 13.702480
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.0%
# Minibatch loss at step 2891: 1.456284
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.6%
# Minibatch loss at step 2892: 5.233353
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.4%
# Minibatch loss at step 2893: 6.270464
# Minibatch accuracy: 79.7%
# Validation accuracy: 81.9%
# Minibatch loss at step 2894: 3.883996
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 2895: 2.544261
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.4%
# Minibatch loss at step 2896: 3.134246
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.0%
# Minibatch loss at step 2897: 4.248704
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.7%
# Minibatch loss at step 2898: 2.323050
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.8%
# Minibatch loss at step 2899: 6.338885
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.5%
# Minibatch loss at step 2900: 2.534973
# Minibatch accuracy: 89.8%
# Validation accuracy: 82.0%
# Minibatch loss at step 2901: 3.448843
# Minibatch accuracy: 80.5%
# Validation accuracy: 82.1%
# Minibatch loss at step 2902: 3.913836
# Minibatch accuracy: 78.1%
# Validation accuracy: 81.6%
# Minibatch loss at step 2903: 1.211868
# Minibatch accuracy: 89.1%
# Validation accuracy: 82.0%
# Minibatch loss at step 2904: 3.061595
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 2905: 3.611571
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.8%
# Minibatch loss at step 2906: 2.061052
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 2907: 2.238574
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.1%
# Minibatch loss at step 2908: 3.438729
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.4%
# Minibatch loss at step 2909: 3.716987
# Minibatch accuracy: 83.6%
# Validation accuracy: 82.6%
# Minibatch loss at step 2910: 4.386931
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 2911: 5.707672
# Minibatch accuracy: 79.7%
# Validation accuracy: 82.2%
# Minibatch loss at step 2912: 3.631288
# Minibatch accuracy: 82.0%
# Validation accuracy: 82.5%
# Minibatch loss at step 2913: 2.733690
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.7%
# Minibatch loss at step 2914: 2.532475
# Minibatch accuracy: 80.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 2915: 4.583601
# Minibatch accuracy: 78.9%
# Validation accuracy: 82.6%
# Minibatch loss at step 2916: 2.007764
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 2917: 1.981095
# Minibatch accuracy: 85.9%
# Validation accuracy: 82.9%
# Minibatch loss at step 2918: 8.476895
# Minibatch accuracy: 75.8%
# Validation accuracy: 81.5%
# Minibatch loss at step 2919: 4.954854
# Minibatch accuracy: 85.2%
# Validation accuracy: 82.6%
# Minibatch loss at step 2920: 1.807441
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.7%
# Minibatch loss at step 2921: 3.233574
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.6%
# Minibatch loss at step 2922: 7.047275
# Minibatch accuracy: 79.7%
# Validation accuracy: 81
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 2969: 1.953431
# Minibatch accuracy: 82.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 2970: 3.491889
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.5%
# Minibatch loss at step 2971: 3.502134
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 2972: 4.962991
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 2973: 2.388953
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 2974: 5.164722
# Minibatch accuracy: 86.7%
# Validation accuracy: 81.1%
# Minibatch loss at step 2975: 2.735823
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 2976: 5.541097
# Minibatch accuracy: 79.7%
# Validation accuracy: 80.9%
# Minibatch loss at step 2977: 2.439492
# Minibatch accuracy: 75.8%
# Validation accuracy: 80.8%
# Minibatch loss at step 2978: 3.845478
# Minibatch accuracy: 76.6%
# Validation accuracy: 80.6%
# Minibatch loss at step 2979: 2.110325
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.0%
# Minibatch loss at step 2980: 5.358717
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.1%
# Minibatch loss at step 2981: 3.199472
# Minibatch accuracy: 82.0%
# Validation accuracy: 79.7%
# Minibatch loss at step 2982: 3.056442
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.8%
# Minibatch loss at step 2983: 5.109741
# Minibatch accuracy: 83.6%
# Validation accuracy: 81.2%
# Minibatch loss at step 2984: 2.501062
# Minibatch accuracy: 80.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 2985: 9.347811
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.5%
# Minibatch loss at step 2986: 2.509250
# Minibatch accuracy: 89.1%
# Validation accuracy: 81.6%
# Minibatch loss at step 2987: 2.244285
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.3%
# Minibatch loss at step 2988: 4.591383
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.6%
# Minibatch loss at step 2989: 3.297830
# Minibatch accuracy: 77.3%
# Validation accuracy: 81.8%
# Minibatch loss at step 2990: 5.618362
# Minibatch accuracy: 85.9%
# Validation accuracy: 81.3%
# Minibatch loss at step 2991: 4.777411
# Minibatch accuracy: 84.4%
# Validation accuracy: 81.2%
# Minibatch loss at step 2992: 3.093063
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.2%
# Minibatch loss at step 2993: 5.022003
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.9%
# Minibatch loss at step 2994: 3.454338
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.2%
# Minibatch loss at step 2995: 3.272268
# Minibatch accuracy: 84.4%
# Validation accuracy: 82.3%
# Minibatch loss at step 2996: 3.578666
# Minibatch accuracy: 78.9%
# Validation accuracy: 81.7%
# Minibatch loss at step 2997: 2.794052
# Minibatch accuracy: 85.2%
# Validation accuracy: 81.5%
# Minibatch loss at step 2998: 2.244820
# Minibatch accuracy: 83.6%
# Validation accuracy: 80.5%
# Minibatch loss at step 2999: 2.549412
# Minibatch accuracy: 86.7%
# Validation accuracy: 82.2%
# Minibatch loss at step 3000: 1.982800
# Minibatch accuracy: 82.8%
# Validation accuracy: 82.3%
# Test accuracy: 89.4%

# %% [markdown]
# ---
# Problem
# -------
#
# Turn the logistic regression example with SGD into a 1-hidden layer neural network with rectified linear units [nn.relu()](https://www.tensorflow.org/versions/r0.7/api_docs/python/nn.html#relu) and 1024 hidden nodes. This model should improve your validation / test accuracy.
#
# ---
